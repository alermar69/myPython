# %%
import sys, os
import re, glob
# from dbfpy import dbf
from dbfread import DBF
import string


def GetProjectDirectory():
    # Tkinter.Tk().withdraw()  # we don't want a full GUI, so keep the root window from appearing
    # folder = tkFileDialog.askdirectory()  # show an "Open" dialog box and return the path to the selected file
    # folder = r'C:\ProgramData\Schneider Electric\Citect SCADA 2016\User\Test1'
    folder = r"c:\ProgramData\AVEVA\Citect SCADA 2018 R2\User\Test1"

    if len(folder) < 3:
        raise Exception("No directory specified in GUI")
    return folder


def getAlarms(folder):
    # Get Alarms
    # anaalm.dbf
    # digalm.dbf
    # hardalm.dbf
    # hresalm.dbf
    # advalm.dbf
    # *alm.dbf

    alarms = dict()

    # pat = re.compile(r'^(ana|dig|hard|hres|adv)alm\.dbf$',re.IGNORECASE)
    # for item in os.listdir(folder):
    # 	if pat.match(item):
    # 		alarmfiles.append(item)
    alarmfiles = glob.glob(os.path.join(folder, '*alm.dbf'))
    print("Found {0} alarm files.\n".format(len(alarmfiles)))

    for almType in alarmfiles:

        # db = dbf.Dbf(almType, new=False)
        db = DBF(alarms, encoding='cp1251', load=True)

        alarms[almType] = []

        for rec in db:
            alarms[almType].append(rec.asDict())

        print("Found {0} alarm{2} in {1}".format(len(alarms[almType]), almType, 's' if (
                    len(alarms[almType]) == 0 or len(alarms[almType]) > 1) else ''))
    return alarms


def getTags(folder):
    # Get Tags
    # variable.dbf
    tags = list()

    tagfiles = glob.glob(os.path.join(folder, 'variable.dbf'))
    print("Found {0} tag files.\n".format(len(tagfiles)))

    for tagfile in tagfiles:
        # db = dbf.Dbf(tagfile, new=False)
        db = DBF(tagfile, encoding='cp1251', load=True)
        for rec in db:
            # tags.append(rec.asDict())
            tags.append(rec)
        print("Found {0} tag{2} in {1}".format(len(tags), tagfile, 's' if (len(tags) == 0 or len(tags) > 1) else ''))
    return tags


def listPages(folder, includePath=True):
    # *.rdb files whose name starts with an underscore don't seem to directly map to pages
    # PageMenu.RDB and !Startup.RDB don't seem to map to pages in Citect
    pages = list()

    # files = glob.glob(os.path.join(folder, 'MS*.rdb'))
    files = glob.glob(os.path.join(folder, '*.rdb'))

    for page in files:
        # If the first character of the filename starts with an underscore don't add it to the list of pages
        if os.path.basename(page)[0] == '_':
            continue

        if includePath:
            pages.append(page)
        else:
            # print os.path.basename(page)
            pages.append(os.path.basename(page))
    return pages


# http://stackoverflow.com/a/17197027
def strings(filename, min=4):
    import string
    result = ""
    with open(filename, "rb") as f:
        for c in str(f.read()):
            if c in string.printable:
                result += c
                continue
            # if len(result) >= min:
            #     yield result
            # result = ""
    return result


# http://stackoverflow.com/a/600612
def mkdir_p(path):
    import os, errno
    try:
        os.makedirs(path)
    except OSError as exc:  # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise


def getCachePage(pagePath):
    mkdir_p('cache')  # make the directory if it doesn't exist
    cachefile = os.path.join('.', 'cache', os.path.basename(pagePath))
    cachefile = os.path.abspath(cachefile)
    # check if the page is already cached # if not cache it
    # if not os.path.isfile(cachefile):
    with open(cachefile, 'w+') as f:
        for line in list(strings(pagePath)):
            f.write(line)

    # return the page
    with open(cachefile) as f:
        lines = f.readlines()
        return ''.join(lines)


def isTagInPage(tag, pagePath):
    # text = getCachePage(pagePath)
    text = str(strings(pagePath))
    return tag in text

# %%
folder = GetProjectDirectory()

# %%
pages = listPages(folder)
tags = getTags(folder)
# page = "C:/Users/bjbourque/Desktop/citect_project_analyzer/SAPPI_FINAL_2008_BB\EQ_IFConv.RDB"
# Out:
# Found 1 tag files.
#
# Found 42 tags in c:\ProgramData\AVEVA\Citect SCADA 2018 R2\User\Test1\variable.dbf

# %%
ms_tags_path = r'C:\Users\Alex\Desktop\MS_tags\ '
for page in pages:
        print("Tags on page '{0}'".format(os.path.basename(page)))
        result = ""

        with open(page, "rb") as f:
            for c in str(f.read()):
                if c in string.printable:
                    result += c
                    continue

        file = open(ms_tags_path[:-1] + format(os.path.basename(page)) + r'.txt', 'w+')
        for tag in tags:
            if tag['NAME'] in result:
                print(tag['NAME'])
                file.write(tag['NAME'] + '\n')
            # MS_tags_list[page.split('MS')[1][:2]] = temp_dict
        file.close()
# Out:
# Tags on page '!EquipControl.RDB'
# Tags on page '!EquipControl_Alarm.RDB'
# Tags on page '!EquipControl_PA.RDB'
# Tags on page '!EquipControl_Tag.RDB'
# Tags on page '!LibAlarmFilterPopup.RDB'
# Tags on page '!Motor_Info.RDB'
# Tags on page '!PageListPanel.RDB'
# Tags on page '!ProcessAnalystPopup.RDB'
# Tags on page '!SEPACStatus.RDB'
# Tags on page '!SEPACStatus_App.RDB'
# Tags on page '!SEPACStatus_Comms.RDB'
# Tags on page '!SEPACStatus_HStby.RDB'
# Tags on page '!SEPACStatus_IO.RDB'
# Tags on page '!SEPACStatus_IOFIP.RDB'
# Tags on page '!SEPACStatus_M340Web.RDB'
# Tags on page '!SEPACStatus_M340Web2.RDB'
# Tags on page '!SEPACStatus_M340Web3.RDB'
# Tags on page '!SEPACStatus_M580Web.RDB'
# Tags on page '!SEPACStatus_M580Web2.RDB'
# Tags on page '!SEPACStatus_M580Web3.RDB'
# Tags on page '!SEPACStatus_PremWeb.RDB'
# Tags on page '!SEPACStatus_PremWeb2.RDB'
# Tags on page '!SEPACStatus_PremWeb3.RDB'
# Tags on page '!SEPACStatus_QuanWeb.RDB'
# Tags on page '!SEPACStatus_QuanWeb2.RDB'
# Tags on page '!SEPACStatus_QuanWeb3.RDB'
# Tags on page '!sg1_xpitune.RDB'
# Tags on page '!Shutdown.RDB'
# Tags on page '!Splash.RDB'
# Tags on page '!Startup.RDB'
# Tags on page 'Alarm.RDB'
# t1
# t2
# Tags on page 'BlankPage_HD1080.RDB'
# t2
# Tags on page 'BlankPage_UHD4K.RDB'
# t2
# Tags on page 'ControlInhibit.RDB'
# t1
# t2
# Tags on page 'DefaultAddCommentForm_HD1080.RDB'
# Tags on page 'DefaultAddCommentForm_UHD4K.RDB'
# Tags on page 'DefaultAddEventForm_HD1080.RDB'
# Tags on page 'DefaultAddEventForm_UHD4K.RDB'
# Tags on page 'DefaultAlarm_HD1080.RDB'
# t1
# t3
# Tags on page 'DefaultAlarm_UHD4K.RDB'
# t3
# t4
# Tags on page 'DefaultBypassForm_HD1080.RDB'
# Tags on page 'DefaultBypassForm_UHD4K.RDB'
# Tags on page 'DefaultFacePlate_HD1080.RDB'
# Tags on page 'DefaultFacePlate_UHD4K.RDB'
# Tags on page 'DefaultHardware_HD1080.RDB'
# Tags on page 'DefaultHardware_UHD4K.RDB'
# Tags on page 'DefaultHeaderbar_HD1080.RDB'
# Tags on page 'DefaultHeaderbar_UHD4K.RDB'
# Tags on page 'DefaultShelved_HD1080.RDB'
# Tags on page 'DefaultShelved_UHD4K.RDB'
# t2
# t4
# Tags on page 'DefaultShelveForm_HD1080.RDB'
# Tags on page 'DefaultShelveForm_UHD4K.RDB'
# Tags on page 'DefaultShelveUntilForm_HD1080.RDB'
# Tags on page 'DefaultShelveUntilForm_UHD4K.RDB'
# Tags on page 'DefaultSoE_HD1080.RDB'
# t4
# Tags on page 'DefaultSoE_UHD4K.RDB'
# t4
# Tags on page 'DefaultTrend_HD1080.RDB'
# Tags on page 'DefaultTrend_UHD4K.RDB'
# Tags on page 'Disabled.RDB'
# t1
# t2
# Tags on page 'ErrorPane.RDB'
# Tags on page 'FacePlateHeader_HD1080.RDB'
# Tags on page 'FacePlateHeader_UHD4K.RDB'
# Tags on page 'FP_AI_HD1080.RDB'
# Tags on page 'FP_AI_UHD4K.RDB'
# Tags on page 'FP_CMPLX_VLV_HD1080.RDB'
# Tags on page 'FP_CMPLX_VLV_UHD4K.RDB'
# Tags on page 'FP_CTRL_HD1080.RDB'
# Tags on page 'FP_CTRL_UHD4K.RDB'
# Tags on page 'FP_DOL_FR_HD1080.RDB'
# Tags on page 'FP_DOL_FR_UHD4K.RDB'
# Tags on page 'FP_DOL_HD1080.RDB'
# t1
# Tags on page 'FP_DOL_UHD4K.RDB'
# t1
# Tags on page 'FP_VLV_HD1080.RDB'
# Tags on page 'FP_VLV_UHD4K.RDB'
# Tags on page 'FP_VSD_FR_HD1080.RDB'
# t2
# Tags on page 'FP_VSD_FR_UHD4K.RDB'
# t1
# Tags on page 'FP_VSD_HD1080.RDB'
# t2
# Tags on page 'FP_VSD_UHD4K.RDB'
# t1
# Tags on page 'Hardware.RDB'
# t1
# t2
# Tags on page 'HelpHeader_HD1080.RDB'
# t4
# Tags on page 'HelpHeader_UHD4K.RDB'
# t4
# Tags on page 'Help_Alarm_HD1080.RDB'
# Tags on page 'Help_Alarm_UHD4K.RDB'
# Tags on page 'Help_Blank_HD1080.RDB'
# t2
# Tags on page 'Help_Blank_UHD4K.RDB'
# t2
# Tags on page 'Help_EquipmentDetail_HD1080.RDB'
# Tags on page 'Help_EquipmentDetail_UHD4K.RDB'
# Tags on page 'Help_Equipment_HD1080.RDB'
# Tags on page 'Help_Equipment_UHD4K.RDB'
# Tags on page 'Help_HD1080.RDB'
# Tags on page 'Help_Meters_HD1080.RDB'
# Tags on page 'Help_Meters_UHD4K.RDB'
# Tags on page 'Help_Navigation_HD1080.RDB'
# Tags on page 'Help_Navigation_UHD4K.RDB'
# Tags on page 'Help_ShortcutKeys_HD1080.RDB'
# Tags on page 'Help_ShortcutKeys_UHD4K.RDB'
# Tags on page 'Help_Status_HD1080.RDB'
# Tags on page 'Help_Status_UHD4K.RDB'
# Tags on page 'Help_UHD4K.RDB'
# Tags on page 'Help_Valves_HD1080.RDB'
# Tags on page 'Help_Valves_UHD4K.RDB'
# Tags on page 'Home_HD1080.RDB'
# Tags on page 'Home_UHD4K.RDB'
# Tags on page 'HTML.RDB'
# t1
# t2
# t3
# Tags on page 'InfoHeader_HD1080.RDB'
# Tags on page 'InfoHeader_UHD4K.RDB'
# Tags on page 'Info_Alarm_HD1080.RDB'
# Tags on page 'Info_Alarm_UHD4K.RDB'
# Tags on page 'Info_Blank_HD1080.RDB'
# t2
# Tags on page 'Info_Blank_UHD4K.RDB'
# t2
# Tags on page 'Info_Interlocks_HD1080.RDB'
# Tags on page 'Info_Interlocks_UHD4K.RDB'
# Tags on page 'Info_Trend_HD1080.RDB'
# t1
# t2
# t3
# t4
# Tags on page 'Info_Trend_UHD4K.RDB'
# t1
# t2
# t3
# t4
# Tags on page 'InterlocksHeader_HD1080.RDB'
# t2
# Tags on page 'InterlocksHeader_UHD4K.RDB'
# t2
# Tags on page 'ManualOverride.RDB'
# t1
# t2
# Tags on page 'Master_PageMenu1_HD1080.RDB'
# Tags on page 'Master_PageMenu1_UHD4K.RDB'
# Tags on page 'My.RDB'
# Test
# t1
# t2
# t3
# t4
# Tags on page 'OptionsPopup.RDB'
# Tags on page 'PageMenu.RDB'
# Tags on page 'PageNav4_1TabRow_HD1080.RDB'
# Tags on page 'PageNav4_1TabRow_UHD4K.RDB'
# Tags on page 'PageNavigation_1TabRow_HD1080.RDB'
# t4
# Tags on page 'PageNavigation_1TabRow_UHD4K.RDB'
# t2
# Tags on page 'ProcessAnalyst.RDB'
# t1
# t2
# Tags on page 'Soe.RDB'
# t1
# t2
# Tags on page 'Startup.RDB'
# t1
# t2
# Tags on page 'SxW_Style_Startup.RDB'
# t1
# t2
# t4
# Tags on page 'Tab_Style_Startup.RDB'
# Tags on page 'Test_HD1080.RDB'
# Test
# Tags on page 'Test_UHD4K.RDB'
# Test
# Tags on page 'TopActiveAlarms_UHD4K.RDB'
# Tags on page 'TopFiveAlarmPopup_HD1080.RDB'
# Tags on page 'VariableTags.RDB'
# t1
# t2
